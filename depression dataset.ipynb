# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\91903\Downloads\playground-series-s4e11\train.csv")

# %%
data
# Out:
#             id      Name  Gender  Age           City  \
# 0            0  Aaradhya  Female   49       Ludhiana
# 1            1     Vivan    Male   26       Varanasi
# 2            2    Yuvraj    Male   33  Visakhapatnam
# 3            3    Yuvraj    Male   22         Mumbai
# 4            4      Rhea  Female   30         Kanpur
# ...        ...       ...     ...  ...            ...
# 140695  140695     Vidya  Female   18      Ahmedabad
# 140696  140696      Lata  Female   41      Hyderabad
# 140697  140697   Aanchal  Female   24        Kolkata
# 140698  140698    Prachi  Female   49       Srinagar
# 140699  140699       Sai    Male   27          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
data.head()
# Out:
#    id      Name  Gender  Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female   49       Ludhiana            Working Professional
# 1   1     Vivan    Male   26       Varanasi            Working Professional
# 2   2    Yuvraj    Male   33  Visakhapatnam                         Student
# 3   3    Yuvraj    Male   22         Mumbai            Working Professional
# 4   4      Rhea  Female   30         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
data["Gender"].value_counts()
# Out:
# Male      77464
# Female    63236
# Name: Gender, dtype: int64

# %%
data['Gender_Numeric']=data['Gender'].map({"Male": 1, "Female": 0})

# %%
data["Gender_Numeric"]
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
#          ..
# 140695    0
# 140696    0
# 140697    0
# 140698    0
# 140699    1
# Name: Gender_Numeric, Length: 140700, dtype: int64

# %%
data.head()
# Out:
#    id      Name  Gender  Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female   49       Ludhiana            Working Professional
# 1   1     Vivan    Male   26       Varanasi            Working Professional
# 2   2    Yuvraj    Male   33  Visakhapatnam                         Student
# 3   3    Yuvraj    Male   22         Mumbai            Working Professional
# 4   4      Rhea  Female   30         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  ...  \
# 0              Chef                NaN            5.0   NaN  ...
# 1           Teacher                NaN            4.0   NaN  ...
# 2               NaN                5.0            NaN  8.97  ...
# 3           Teacher                NaN            5.0   NaN  ...
# 4  Business Analyst                NaN            1.0   NaN  ...
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# ...

# %%
data.drop(columns=["Gender"], inplace=True)

# %%
data
# Out:
#             id      Name  Age           City Working Professional or Student  \
# 0            0  Aaradhya   49       Ludhiana            Working Professional
# 1            1     Vivan   26       Varanasi            Working Professional
# 2            2    Yuvraj   33  Visakhapatnam                         Student
# 3            3    Yuvraj   22         Mumbai            Working Professional
# 4            4      Rhea   30         Kanpur            Working Professional
# ...        ...       ...  ...            ...                             ...
# 140695  140695     Vidya   18      Ahmedabad            Working Professional
# 140696  140696      Lata   41      Hyderabad            Working Professional
# 140697  140697   Aanchal   24        Kolkata            Working Professional
# 140698  140698    Prachi   49       Srinagar            Working Professional
# 140699  140699       Sai   27          Patna                         Student
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler=MinMaxScaler()
data["Age_Normalized"]=scaler.fit_transform(data["Age"].values.reshape(-1,1))

# %%
data.head()
# Out:
#    id      Name  Age           City Working Professional or Student  \
# 0   0  Aaradhya   49       Ludhiana            Working Professional
# 1   1     Vivan   26       Varanasi            Working Professional
# 2   2    Yuvraj   33  Visakhapatnam                         Student
# 3   3    Yuvraj   22         Mumbai            Working Professional
# 4   4      Rhea   30         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  ...     Sleep Duration Dietary Habits   Degree  \
# 0                 NaN  ...  More than 8 hours        Healthy      BHM
# ...

# %%
data.drop(columns=["Age"], inplace=True)

# %%
data.head()
# Out:
#    id      Name           City Working Professional or Student  \
# 0   0  Aaradhya       Ludhiana            Working Professional
# 1   1     Vivan       Varanasi            Working Professional
# 2   2    Yuvraj  Visakhapatnam                         Student
# 3   3    Yuvraj         Mumbai            Working Professional
# 4   4      Rhea         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
data["City"].nunique()
# Out:
# 98

# %%
data["City"].unique()
# Out:
# array(['Ludhiana', 'Varanasi', 'Visakhapatnam', 'Mumbai', 'Kanpur',
#        'Ahmedabad', 'Thane', 'Nashik', 'Bangalore', 'Patna', 'Rajkot',
#        'Jaipur', 'Pune', 'Lucknow', 'Meerut', 'Agra', 'Surat',
#        'Faridabad', 'Hyderabad', 'Srinagar', 'Ghaziabad', 'Kolkata',
#        'Chennai', 'Kalyan', 'Nagpur', 'Vadodara', 'Vasai-Virar', 'Delhi',
#        'Bhopal', 'Indore', 'Ishanabad', 'Vidhi', 'Ayush', 'Gurgaon',
#        'Krishna', 'Aishwarya', 'Keshav', 'Harsha', 'Nalini', 'Aditya',
#        'Malyansh', 'Raghavendra', 'Saanvi', 'M.Tech', 'Bhavna',
#        'Less Delhi', 'Nandini', 'M.Com', 'Plata', 'Atharv', 'Pratyush',
#        'City', '3', 'Less than 5 Kalyan', 'MCA', 'Mira', 'Moreadhyay',
#        'Morena', 'Ishkarsh', 'Kashk', 'Mihir', 'Vidya', 'Tolkata', 'Anvi',
#        'Krinda', 'Ayansh', 'Shrey', 'Ivaan', 'Vaanya', 'Gaurav', 'Harsh',
#        'Reyansh', 'Kashish', 'Kibara', 'Vaishnavi', 'Chhavi', 'Parth',
# ...

# %%
data["Working Professional or Student"].value_counts()
# Out:
# Working Professional    112799
# Student                  27901
# Name: Working Professional or Student, dtype: int64

# %%
data["Profession"].isnull().sum()
# Out:
# 36630

# %%
data["Profession"]=data["Profession"].fillna('Student')

# %%
data.head()
# Out:
#    id      Name           City Working Professional or Student  \
# 0   0  Aaradhya       Ludhiana            Working Professional
# 1   1     Vivan       Varanasi            Working Professional
# 2   2    Yuvraj  Visakhapatnam                         Student
# 3   3    Yuvraj         Mumbai            Working Professional
# 4   4      Rhea         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2           Student                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction  ... Dietary Habits   Degree  \
# 0                 NaN               2.0  ...        Healthy      BHM
# 1                 NaN               3.0  ...      Unhealthy      LLB
# ...

# %%
data.drop(columns=["Working Professional or Student"], inplace=True)

# %%
data.head()
# Out:
#    id      Name           City        Profession  Academic Pressure  \
# 0   0  Aaradhya       Ludhiana              Chef                NaN
# 1   1     Vivan       Varanasi           Teacher                NaN
# 2   2    Yuvraj  Visakhapatnam           Student                5.0
# 3   3    Yuvraj         Mumbai           Teacher                NaN
# 4   4      Rhea         Kanpur  Business Analyst                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            5.0   NaN                 NaN               2.0
# 1            4.0   NaN                 NaN               3.0
# 2            NaN  8.97                 2.0               NaN
# 3            5.0   NaN                 NaN               1.0
# 4            1.0   NaN                 NaN               1.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0  More than 8 hours        Healthy      BHM
# 1  Less than 5 hours      Unhealthy      LLB
# 2          5-6 hours        Healthy  B.Pharm
# ...

# %%
data["Academic_Work_Pressure"]=data["Academic Pressure"].fillna(data["Work Pressure"])

# %%
data.head()
# Out:
#    id      Name           City        Profession  Academic Pressure  \
# 0   0  Aaradhya       Ludhiana              Chef                NaN
# 1   1     Vivan       Varanasi           Teacher                NaN
# 2   2    Yuvraj  Visakhapatnam           Student                5.0
# 3   3    Yuvraj         Mumbai           Teacher                NaN
# 4   4      Rhea         Kanpur  Business Analyst                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            5.0   NaN                 NaN               2.0
# 1            4.0   NaN                 NaN               3.0
# 2            NaN  8.97                 2.0               NaN
# 3            5.0   NaN                 NaN               1.0
# 4            1.0   NaN                 NaN               1.0
#
#       Sleep Duration  ...   Degree Have you ever had suicidal thoughts ?  \
# 0  More than 8 hours  ...      BHM                                    No
# ...

# %%
data.drop(columns=["Academic Pressure"], inplace=True)
data.drop(columns=["Work Pressure"], inplace=True)

# %%
data.head()
# Out:
#    id      Name           City        Profession  CGPA  Study Satisfaction  \
# 0   0  Aaradhya       Ludhiana              Chef   NaN                 NaN
# 1   1     Vivan       Varanasi           Teacher   NaN                 NaN
# 2   2    Yuvraj  Visakhapatnam           Student  8.97                 2.0
# 3   3    Yuvraj         Mumbai           Teacher   NaN                 NaN
# 4   4      Rhea         Kanpur  Business Analyst   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# 1               3.0  Less than 5 hours      Unhealthy      LLB
# 2               NaN          5-6 hours        Healthy  B.Pharm
# 3               1.0  Less than 5 hours       Moderate      BBA
# 4               1.0          5-6 hours      Unhealthy      BBA
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# ...

# %%
data["Job_Study_Satisfaction"]=data["Study Satisfaction"].fillna(data["Job Satisfaction"])

# %%
data.head()
# Out:
#    id      Name           City        Profession  CGPA  Study Satisfaction  \
# 0   0  Aaradhya       Ludhiana              Chef   NaN                 NaN
# 1   1     Vivan       Varanasi           Teacher   NaN                 NaN
# 2   2    Yuvraj  Visakhapatnam           Student  8.97                 2.0
# 3   3    Yuvraj         Mumbai           Teacher   NaN                 NaN
# 4   4      Rhea         Kanpur  Business Analyst   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# 1               3.0  Less than 5 hours      Unhealthy      LLB
# 2               NaN          5-6 hours        Healthy  B.Pharm
# 3               1.0  Less than 5 hours       Moderate      BBA
# 4               1.0          5-6 hours      Unhealthy      BBA
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# ...

# %%
data.drop(columns=["Study Satisfaction"], inplace=True)
data.drop(columns=["Job Satisfaction"], inplace=True)

# %%
data.head()
# Out:
#    id      Name           City        Profession  CGPA     Sleep Duration  \
# 0   0  Aaradhya       Ludhiana              Chef   NaN  More than 8 hours
# 1   1     Vivan       Varanasi           Teacher   NaN  Less than 5 hours
# 2   2    Yuvraj  Visakhapatnam           Student  8.97          5-6 hours
# 3   3    Yuvraj         Mumbai           Teacher   NaN  Less than 5 hours
# 4   4      Rhea         Kanpur  Business Analyst   NaN          5-6 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy      BHM                                    No
# 1      Unhealthy      LLB                                   Yes
# 2        Healthy  B.Pharm                                   Yes
# 3       Moderate      BBA                                   Yes
# 4      Unhealthy      BBA                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# ...

# %%
data['Have you ever had suicidal thoughts ?']=data['Have you ever had suicidal thoughts ?'].map({"Yes": 1, "No": 0})

# %%
data.head()
# Out:
#    id      Name           City        Profession  CGPA     Sleep Duration  \
# 0   0  Aaradhya       Ludhiana              Chef   NaN  More than 8 hours
# 1   1     Vivan       Varanasi           Teacher   NaN  Less than 5 hours
# 2   2    Yuvraj  Visakhapatnam           Student  8.97          5-6 hours
# 3   3    Yuvraj         Mumbai           Teacher   NaN  Less than 5 hours
# 4   4      Rhea         Kanpur  Business Analyst   NaN          5-6 hours
#
#   Dietary Habits   Degree  Have you ever had suicidal thoughts ?  \
# 0        Healthy      BHM                                      0
# 1      Unhealthy      LLB                                      1
# 2        Healthy  B.Pharm                                      1
# 3       Moderate      BBA                                      1
# 4      Unhealthy      BBA                                      1
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# ...

# %%
data["Family History of Mental Illness"].value_counts()
# Out:
# No     70758
# Yes    69942
# Name: Family History of Mental Illness, dtype: int64

# %%
data['Family History of Mental Illness']=data['Family History of Mental Illness'].map({"Yes": 1, "No": 0})

# %%
data.head()
# Out:
#    id      Name           City        Profession  CGPA     Sleep Duration  \
# 0   0  Aaradhya       Ludhiana              Chef   NaN  More than 8 hours
# 1   1     Vivan       Varanasi           Teacher   NaN  Less than 5 hours
# 2   2    Yuvraj  Visakhapatnam           Student  8.97          5-6 hours
# 3   3    Yuvraj         Mumbai           Teacher   NaN  Less than 5 hours
# 4   4      Rhea         Kanpur  Business Analyst   NaN          5-6 hours
#
#   Dietary Habits   Degree  Have you ever had suicidal thoughts ?  \
# 0        Healthy      BHM                                      0
# 1      Unhealthy      LLB                                      1
# 2        Healthy  B.Pharm                                      1
# 3       Moderate      BBA                                      1
# 4      Unhealthy      BBA                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# ...

# %%
data["Dietary Habits"].value_counts()
# Out:
# Moderate             49705
# Unhealthy            46227
# Healthy              44741
# Yes                      2
# No                       2
# More Healthy             2
# No Healthy               1
# Class 12                 1
# Indoor                   1
# Male                     1
# Vegas                    1
# M.Tech                   1
# Less Healthy             1
# 1                        1
# Electrician              1
# Hormonal                 1
# Mihir                    1
# Less than Healthy        1
# 3                        1
# Gender                   1
# BSc                      1
# Pratham                  1
# 2                        1
# Name: Dietary Habits, dtype: int64

# %%
data["Degree"].value_counts()
# Out:
# Class 12    14729
# B.Ed        11691
# B.Arch       8742
# B.Com        8113
# B.Pharm      5856
#             ...
# Vivaan          1
# MTech           1
# 29              1
# LLCom           1
# Advait          1
# Name: Degree, Length: 115, dtype: int64

# %%
data["Sleep Duration"].value_counts()
# Out:
# Less than 5 hours    38784
# 7-8 hours            36969
# More than 8 hours    32726
# 5-6 hours            32142
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 2-3 hours                5
# 4-6 hours                5
# 6-8 hours                4
# 1-6 hours                4
# No                       4
# 9-11 hours               2
# 10-11 hours              2
# Sleep_Duration           2
# Unhealthy                2
# 45                       2
# 8-9 hours                2
# 10-6 hours               1
# 09-May                   1
# 45-48 hours              1
# 3-6 hours                1
# Work_Study_Hours         1
# 49 hours                 1
# than 5 hours             1
# Pune                     1
# 9-6 hours                1
# 8 hours                  1
# 35-36 hours              1
# Indore                   1
# 1-3 hours                1
# 55-66 hours              1
# Moderate                 1
# 40-45 hours              1
# ...
